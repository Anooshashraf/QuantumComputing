# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from qiskit import QuantumCircuit
#       2 from qiskit.quantum_info import Statevector
#
# File ~\anaconda3\envs\qiskit-env\Lib\site-packages\qiskit\__init__.py:118
#     115 from qiskit.exceptions import QiskitError, MissingOptionalLibraryError
#     117 # The main qiskit operators
# --> 118 from qiskit.circuit import ClassicalRegister
#     119 from qiskit.circuit import QuantumRegister
#     120 from qiskit.circuit import AncillaRegister
#
# File ~\anaconda3\envs\qiskit-env\Lib\site-packages\qiskit\circuit\__init__.py:1278
#    1276 from .exceptions import CircuitError
#    1277 from . import _utils
# -> 1278 from .quantumcircuit import QuantumCircuit
#    1279 from .classicalregister import ClassicalRegister, Clbit
# ...

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
qc.draw()
